# %% [markdown]
# # Spatial Analysis and Modeling
#
# ### Instructor: Rossano Schifanella
# Email: [rossano.schifanella@unito.it](mailto:rossano.schifanella@unito.it)
#
# ## Represent Spatial Data

# %% [markdown]
# ## Exercise 3
#
# In this exercise you will learn how to:
# * Use Python to load data from a shapefile, CSV or a GeoJSON datasource
# * Perform spatial functions
# * Boost the performance: indexing and prepared geometries

# %% [markdown]
# ### Define basic transformation functions
#
# Basic functions to transform SRID of Point, Polygon or MultiPolygon

# %%
from pyproj import Proj, transform

def transform_point(SRID_from, SRID_to, point):
    p_in    = Proj("+init=%s" %SRID_from)
    p_out   = Proj("+init=%s" %SRID_to)
    return transform(p_in, p_out, point[0], point[1])

def transform_polygon(SRID_from, SRID_to, geometry):
    coordinates = []
    for polygon in geometry:
        projected_coordinates = []
        for p in polygon:
            projected_coordinates.append(transform_point(SRID_from, SRID_to, p))
        coordinates.append(projected_coordinates)
    return coordinates

def transform_multipolygon(SRID_from, SRID_to, multipolygon):
    projected_coordinates = []
    for polygon in multipolygon:
        projected_coordinates.append(transform_polygon(SRID_from, SRID_from, polygon))
    return projected_coordinates

# %% [markdown]
# ### Load data from a shapefile
#
# Load a shapefile from a local file and create a _shapely_ object for each geometry feature

# %%
from shapely.geometry import *
import fiona

neighborhoods2geometry = {}

with fiona.open('../data/shp/nyc_neighborhoods/nyc_neighborhoods.shp', 'r') as source:
    print("Shapefile CRS = %s" %source.crs['init'])
    for f in source:
        try:
            neighborhoods2geometry[f['properties']['NAME']] = shape(f['geometry'])
        except Exception as ex:
            print(ex)

print("Loaded %d features (attributes: %s)" %(len(neighborhoods2geometry), f['properties'].keys()))
# Out:
# Shapefile CRS = epsg:26918
# Loaded 129 features (attributes: odict_keys(['BORONAME', 'NAME']))

# %% [markdown]
# ### Load crime data
#
# Load crime data from a local CSV file and:
#
# * Transform the original coordinates system (EPSG:4326) to the same SRID used with the neighborhood data (EPSG:26918)
# * Create a _shapely_ Point for each crime event
# * Save additional information on a crime event

# %%
from shapely.geometry import Point
from datetime import datetime
import csv

crime_data_file = '../data/crime/nyc_crime.csv'

crime_events = []
print("loading crime data from %s..." %crime_data_file)
with open(crime_data_file, 'r') as f:
    reader = csv.DictReader(f)
    for row in reader:
#       Transform crime event location data from EPSG:4326 to EPSG:26918 SRID (same of the neighborhoods shapefile)  
        projected_coordinates = transform_point("EPSG:4326","EPSG:26918", (row['longitude'], row['latitude']))
        crime_event_location = Point(projected_coordinates)
        crime_events.append({
            'type': row['Offense'],
            'category': row['Offense Classification'],
            'geom': crime_event_location,
            'date': datetime.strptime(row['Occurrence Date'], '%m/%d/%Y %H:%M:%S %p'),
        })

print("loaded %s crime events." %len(crime_events))
# Out:
# loading crime data from ../data/crime/nyc_crime.csv...
# loaded 102657 crime events.

# %% [markdown]
# ### Perform spatial functions on Python geometry objects
#
# In this section we will describe how to compute the most frequent type of crime and its relative frequency for each neighborhood in New York City. We will consider only 10.000 crime instances due to performance issues in computing the spatial function _within_ without the use of indexes or any other performance improvement.

# %%
import operator 
import time

neighborhood2crime_distribution = {}

start_time = time.time()
for current in crime_events[:10000]:
    
    crime_type = current['type']

    for neighborhood_name in neighborhoods2geometry: 
        
        neighborhood_geom = neighborhoods2geometry[neighborhood_name]
        
        if current['geom'].within(neighborhood_geom):
            neighborhood2crime_distribution.setdefault(neighborhood_name, {})
            neighborhood2crime_distribution[neighborhood_name].setdefault(crime_type, 0)
            neighborhood2crime_distribution[neighborhood_name][crime_type]+=1
            break

print("Time elapsed: %s seconds\n" % (time.time() - start_time))

for neighborhood_name in neighborhood2crime_distribution:
    most_frequent_crime = max(
                            neighborhood2crime_distribution[neighborhood_name].items(), 
                            key=operator.itemgetter(1))[0]
    n_events_most_frequent_crime = neighborhood2crime_distribution[neighborhood_name][most_frequent_crime]
    total_crimes = sum(neighborhood2crime_distribution[neighborhood_name].values())
    
    print("%25s\t%30s\t%s\t%.2f" %(neighborhood_name, 
                                   most_frequent_crime, 
                                   n_events_most_frequent_crime,
                                   (n_events_most_frequent_crime/total_crimes)*100))
# Out:
# Time elapsed: 4.2206902503967285 seconds
#
#               East Harlem	                 GRAND LARCENY	40	37.38
#              Williamsburg	                 GRAND LARCENY	73	38.83
#                   Midtown	                 GRAND LARCENY	193	75.10
#         North Sutton Area	                 GRAND LARCENY	10	83.33
#               South Bronx	                FELONY ASSAULT	107	34.74
#                Fort Green	                 GRAND LARCENY	58	37.42
#              East Village	                 GRAND LARCENY	49	55.68
#                   Chelsea	                 GRAND LARCENY	102	67.55
#               Brownsville	                 GRAND LARCENY	53	25.48
#                 Riverdale	                 GRAND LARCENY	15	65.22
#                  Canarsie	                 GRAND LARCENY	67	44.08
#           Upper West Side	                 GRAND LARCENY	133	66.50
#             Midland Beach	                 GRAND LARCENY	8	66.67
#         Greenwich Village	                 GRAND LARCENY	81	73.64
#           Jackson Heights	                 GRAND LARCENY	50	40.65
#               High Bridge	                 GRAND LARCENY	56	38.10
#           Williams Bridge	                 GRAND LARCENY	18	34.62
#             Dyker Heights	                 GRAND LARCENY	9	40.91
#                   Clinton	                 GRAND LARCENY	43	67.19
#                 Soundview	                FELONY ASSAULT	37	28.24
#                    Harlem	                FELONY ASSAULT	77	32.35
#                   Oakwood	                 GRAND LARCENY	10	50.00
#  Gravesend-Sheepshead Bay	                 GRAND LARCENY	81	38.21
#             East Brooklyn	                 GRAND LARCENY	78	28.57
#               Boerum Hill	                 GRAND LARCENY	18	56.25
#                    Utopia	                       ROBBERY	20	35.09
#              West Village	                 GRAND LARCENY	43	68.25
#                Mott Haven	                 GRAND LARCENY	48	32.88
#               Saintalbans	                 GRAND LARCENY	24	34.78
#  Astoria-Long Island City	                 GRAND LARCENY	44	34.38
#        Mapleton-Flatlands	                 GRAND LARCENY	55	30.05
#          Hamilton Heights	                 GRAND LARCENY	27	31.03
#                   Jamaica	                 GRAND LARCENY	83	32.81
#        Washington Heights	                 GRAND LARCENY	66	37.29
#              Borough Park	                 GRAND LARCENY	42	44.21
#                   Fordham	                FELONY ASSAULT	39	33.91
#       Springfield Gardens	                FELONY ASSAULT	19	37.25
#                Baychester	                       ROBBERY	5	31.25
#        Bedford-Stuyvesant	                 GRAND LARCENY	123	28.87
#            Queens Village	                 GRAND LARCENY	17	31.48
#           Lower East Side	                 GRAND LARCENY	72	56.25
#               Hunts Point	                FELONY ASSAULT	27	45.00
#                Auburndale	                 GRAND LARCENY	10	52.63
#                 Laurelton	                FELONY ASSAULT	10	26.32
#          Garment District	                 GRAND LARCENY	103	74.10
#   Woodhaven-Richmond Hill	                 GRAND LARCENY	36	30.77
#                  Flushing	                 GRAND LARCENY	51	58.62
#                  Gramercy	                 GRAND LARCENY	137	73.26
#           Upper East Side	                 GRAND LARCENY	122	70.52
#       Morningside Heights	                 GRAND LARCENY	24	70.59
#        University Heights	                 GRAND LARCENY	15	29.41
#               Eastchester	                 GRAND LARCENY	8	38.10
#                  Bushwick	                      BURGLARY	57	30.48
#             The Rockaways	                FELONY ASSAULT	49	37.69
#                 Yorkville	                FELONY ASSAULT	24	31.17
#        Financial District	                 GRAND LARCENY	44	81.48
#               Cobble Hill	                      BURGLARY	6	54.55
#                Sunny Side	                 GRAND LARCENY	23	37.70
#                 Greenwood	                      BURGLARY	5	26.32
#               Bensonhurst	                 GRAND LARCENY	28	38.36
#               Sunset Park	                 GRAND LARCENY	29	38.16
#                  Downtown	                 GRAND LARCENY	27	65.85
#              Bedford Park	                 GRAND LARCENY	42	33.60
#                   Tremont	                FELONY ASSAULT	62	36.26
#              Throggs Neck	                 GRAND LARCENY	18	43.90
#                   Clifton	                       ROBBERY	10	27.03
#   Douglastown-Little Neck	                 GRAND LARCENY	31	58.49
#              Little Italy	                 GRAND LARCENY	17	62.96
#           Queensboro Hill	                 GRAND LARCENY	11	39.29
#           Mariners Harbor	                FELONY ASSAULT	12	30.00
#  Wakefield-Williamsbridge	                FELONY ASSAULT	49	32.45
#                   Tribeca	                 GRAND LARCENY	21	65.62
#              Kings Bridge	                 GRAND LARCENY	17	40.48
#                 Bay Ridge	                 GRAND LARCENY	18	30.51
#                      Soho	                 GRAND LARCENY	49	89.09
#              Richmondtown	                 GRAND LARCENY	13	61.90
#               Murray Hill	                 GRAND LARCENY	40	78.43
#                Union Port	                 GRAND LARCENY	18	33.96
#               South Beach	                FELONY ASSAULT	8	47.06
#              Central Park	                 GRAND LARCENY	16	53.33
#              New Brighton	                 GRAND LARCENY	18	37.50
#            Morris Heights	                FELONY ASSAULT	26	37.68
#                    Inwood	                 GRAND LARCENY	18	35.29
#               Morris Park	                 GRAND LARCENY	20	41.67
#                   Maspeth	                 GRAND LARCENY	9	28.12
#         Woodlawn-Nordwood	                 GRAND LARCENY	5	31.25
#              Nkew Gardens	                 GRAND LARCENY	24	42.11
#               Parkchester	                 GRAND LARCENY	23	35.94
#                Park Slope	                 GRAND LARCENY	32	46.38
#            Middle Village	                 GRAND LARCENY	7	53.85
#                  Glendale	                 GRAND LARCENY	13	46.43
#              Forest Hills	                 GRAND LARCENY	33	53.23
#            Spuyten Duyvil	                 GRAND LARCENY	5	83.33
#                 Ridgewood	                      BURGLARY	15	25.00
#                  Woodside	                      BURGLARY	9	33.33
#              Country Club	                 GRAND LARCENY	26	53.06
#     Westerleigh-Castleton	                      BURGLARY	4	36.36
#                 Chinatown	                 GRAND LARCENY	11	55.00
#             Port Richmond	                       ROBBERY	9	52.94
#               Great Kills	                 GRAND LARCENY	4	80.00
#           Carroll Gardens	                 GRAND LARCENY	14	45.16
#                   Woodrow	                 GRAND LARCENY	2	66.67
#              Prince's Bay	                      BURGLARY	2	50.00
#                 Clearview	                 GRAND LARCENY	7	50.00
#              Tottensville	                 GRAND LARCENY	3	60.00
#               Ettingville	                 GRAND LARCENY	5	38.46
#             Ardon Heights	                 GRAND LARCENY	3	42.86
#              Battery Park	                 GRAND LARCENY	5	100.00
#                 Todt Hill	                 GRAND LARCENY	6	75.00
#             Carnegie Hill	                 GRAND LARCENY	5	62.50
#                 Rossville	                 GRAND LARCENY	2	66.67
#              Howland Hook	                 GRAND LARCENY	2	66.67
# Bloomfield-Chelsea-Travis	                 GRAND LARCENY	1	33.33
#               City Island	                       ROBBERY	1	50.00
# Charlestown-Richmond Valley	                      BURGLARY	1	100.00
#                  Flatbush	                       ROBBERY	1	100.00
#                  Huguenot	                      BURGLARY	1	100.00

# %% [markdown]
# ### Speed up the computation with indexes and prepared geometries
#
# To improve the running time of spatial functions (especially if the operation is repeated many times on the same geometry) we can use the following basic strategies:
#
# * Create a rtree index that contains the bounding box of the neighborhood shapes
# * Simplify (preserving the topology) the neighborhood shapes
# * Create prepared geometries for each simplified neighborhood that greatly improve the performance of repeated spatil operations
#
# Note that with these simple improvements we are able to process the entire crime dataset (>100K events) in almost the same time than the previous example (only 10K istances)

# %%
from shapely.prepared import prep
from rtree import index

# Create an index with the neighborhoods  
idx = index.Index()

id2neigh = {}
neighborhoods2prepared_geometry = {}

start_time = time.time()

for i, neigh in enumerate(neighborhoods2geometry):

    id2neigh[i] = neigh    
    idx.insert(i, neighborhoods2geometry[neigh].bounds)
    neighborhoods2prepared_geometry[neigh] = prep(neighborhoods2geometry[neigh].simplify(0.5, preserve_topology=True))
    
neighborhood2crime_distribution = {}

for current in crime_events:
    
    crime_type = current['type']
    
    for j in idx.intersection(current['geom'].bounds):
        
        if neighborhoods2prepared_geometry[id2neigh[j]].contains(current['geom']):
            neighborhood2crime_distribution.setdefault(id2neigh[j], {})
            neighborhood2crime_distribution[id2neigh[j]].setdefault(crime_type, 0)
            neighborhood2crime_distribution[id2neigh[j]][crime_type]+=1
            break
            
print("Time elapsed: %s seconds\n" % (time.time() - start_time))

for neighborhood_name in neighborhood2crime_distribution:
    most_frequent_crime = max(
                            neighborhood2crime_distribution[neighborhood_name].items(), 
                            key=operator.itemgetter(1))[0]
    n_events_most_frequent_crime = neighborhood2crime_distribution[neighborhood_name][most_frequent_crime]
    total_crimes = sum(neighborhood2crime_distribution[neighborhood_name].values())
    
    print("%25s\t%30s\t%s\t%.2f" %(neighborhood_name, 
                                   most_frequent_crime, 
                                   n_events_most_frequent_crime,
                                   (n_events_most_frequent_crime/total_crimes)*100))
# Out:
# Time elapsed: 6.630674123764038 seconds
#
#               East Harlem	                FELONY ASSAULT	346	32.34
#              Williamsburg	                 GRAND LARCENY	691	39.00
#                   Midtown	                 GRAND LARCENY	2141	76.00
#         North Sutton Area	                 GRAND LARCENY	85	72.65
#               South Bronx	                FELONY ASSAULT	1032	31.11
#                Fort Green	                 GRAND LARCENY	659	38.11
#              East Village	                 GRAND LARCENY	625	62.69
#                   Chelsea	                 GRAND LARCENY	1060	69.42
#               Brownsville	                FELONY ASSAULT	560	29.79
#                 Riverdale	                 GRAND LARCENY	133	57.58
#                  Canarsie	                 GRAND LARCENY	697	40.64
#           Upper West Side	                 GRAND LARCENY	1127	64.44
#             Midland Beach	                 GRAND LARCENY	51	43.59
#         Greenwich Village	                 GRAND LARCENY	908	74.00
#           Jackson Heights	                 GRAND LARCENY	585	41.49
#               High Bridge	                 GRAND LARCENY	455	32.97
#           Williams Bridge	                 GRAND LARCENY	166	30.02
#             Dyker Heights	                 GRAND LARCENY	84	35.00
#                   Clinton	                 GRAND LARCENY	378	60.38
#                 Soundview	                FELONY ASSAULT	405	27.27
#                    Harlem	                 GRAND LARCENY	734	32.61
#                   Oakwood	                 GRAND LARCENY	78	57.35
#  Gravesend-Sheepshead Bay	                 GRAND LARCENY	862	40.80
#             East Brooklyn	                 GRAND LARCENY	846	31.57
#               Boerum Hill	                 GRAND LARCENY	157	43.73
#                    Utopia	                 GRAND LARCENY	234	39.39
#              West Village	                 GRAND LARCENY	452	72.55
#                Mott Haven	                 GRAND LARCENY	535	31.77
#               Saintalbans	                 GRAND LARCENY	203	27.43
#  Astoria-Long Island City	                 GRAND LARCENY	480	37.44
#        Mapleton-Flatlands	                 GRAND LARCENY	700	38.50
#          Hamilton Heights	                 GRAND LARCENY	282	35.38
#                   Jamaica	                 GRAND LARCENY	718	32.00
#        Washington Heights	                 GRAND LARCENY	634	36.82
#              Borough Park	                 GRAND LARCENY	347	38.73
#                   Fordham	                 GRAND LARCENY	398	31.09
#       Springfield Gardens	                 GRAND LARCENY	129	29.52
#                Baychester	                 GRAND LARCENY	63	33.16
#        Bedford-Stuyvesant	                 GRAND LARCENY	1227	27.82
#            Queens Village	                 GRAND LARCENY	165	31.49
#           Lower East Side	                 GRAND LARCENY	621	53.58
#               Hunts Point	                FELONY ASSAULT	161	32.07
#                Auburndale	                 GRAND LARCENY	97	40.42
#                 Laurelton	                 GRAND LARCENY	132	28.51
#          Garment District	                 GRAND LARCENY	1198	74.09
#   Woodhaven-Richmond Hill	                 GRAND LARCENY	341	26.85
#                  Flushing	                 GRAND LARCENY	489	51.97
#                  Gramercy	                 GRAND LARCENY	1110	66.99
#           Upper East Side	                 GRAND LARCENY	1270	72.74
#       Morningside Heights	                 GRAND LARCENY	191	52.91
#        University Heights	                FELONY ASSAULT	189	28.68
#               Eastchester	                 GRAND LARCENY	68	31.48
#                  Bushwick	                      BURGLARY	476	27.14
#             The Rockaways	                FELONY ASSAULT	456	32.92
#                 Yorkville	                 GRAND LARCENY	248	33.70
#        Financial District	                 GRAND LARCENY	462	75.61
#               Cobble Hill	                 GRAND LARCENY	53	54.08
#                Sunny Side	                 GRAND LARCENY	275	43.10
#                 Greenwood	                 GRAND LARCENY	74	40.22
#               Bensonhurst	                 GRAND LARCENY	280	38.94
#               Sunset Park	                 GRAND LARCENY	294	30.91
#                  Downtown	                 GRAND LARCENY	363	69.94
#              Bedford Park	                 GRAND LARCENY	348	31.52
#                   Tremont	                FELONY ASSAULT	594	31.83
#              Throggs Neck	                 GRAND LARCENY	165	41.15
#                   Clifton	                 GRAND LARCENY	107	32.42
#   Douglastown-Little Neck	                 GRAND LARCENY	309	50.41
#              Little Italy	                 GRAND LARCENY	98	60.87
#           Queensboro Hill	                 GRAND LARCENY	141	37.20
#           Mariners Harbor	                 GRAND LARCENY	103	30.38
#  Wakefield-Williamsbridge	                FELONY ASSAULT	447	30.76
#                   Tribeca	                 GRAND LARCENY	250	70.42
#              Kings Bridge	                 GRAND LARCENY	174	41.83
#                 Bay Ridge	                 GRAND LARCENY	253	40.68
#                      Soho	                 GRAND LARCENY	480	80.94
#              Richmondtown	                 GRAND LARCENY	141	62.95
#               Murray Hill	                 GRAND LARCENY	300	69.77
#                Union Port	                 GRAND LARCENY	173	30.62
#               South Beach	                 GRAND LARCENY	58	34.52
#              Central Park	                 GRAND LARCENY	143	69.08
#              New Brighton	                 GRAND LARCENY	167	31.10
#            Morris Heights	                FELONY ASSAULT	234	30.79
#                    Inwood	                 GRAND LARCENY	202	39.30
#               Morris Park	                 GRAND LARCENY	182	36.18
#                   Maspeth	                 GRAND LARCENY	102	39.08
#         Woodlawn-Nordwood	                 GRAND LARCENY	45	33.09
#              Nkew Gardens	                 GRAND LARCENY	244	40.40
#               Parkchester	                 GRAND LARCENY	322	38.06
#                Park Slope	                 GRAND LARCENY	354	49.65
#            Middle Village	                 GRAND LARCENY	81	42.63
#                  Glendale	                 GRAND LARCENY	108	41.70
#              Forest Hills	                 GRAND LARCENY	296	49.09
#            Spuyten Duyvil	                 GRAND LARCENY	61	67.03
#                 Ridgewood	                 GRAND LARCENY	265	36.01
#                  Woodside	                 GRAND LARCENY	122	32.88
#              Country Club	                 GRAND LARCENY	230	51.69
#     Westerleigh-Castleton	                 GRAND LARCENY	66	45.52
#                 Chinatown	                 GRAND LARCENY	98	51.31
#             Port Richmond	                FELONY ASSAULT	77	29.39
#               Great Kills	                 GRAND LARCENY	20	40.00
#           Carroll Gardens	                 GRAND LARCENY	146	42.69
#                   Woodrow	                 GRAND LARCENY	15	51.72
#              Prince's Bay	                 GRAND LARCENY	20	46.51
#                 Clearview	                 GRAND LARCENY	95	55.56
#              Tottensville	                 GRAND LARCENY	28	49.12
#               Ettingville	                 GRAND LARCENY	51	43.97
#             Ardon Heights	                 GRAND LARCENY	33	56.90
#              Battery Park	                 GRAND LARCENY	59	83.10
#                 Todt Hill	                 GRAND LARCENY	38	45.24
#             Carnegie Hill	                 GRAND LARCENY	71	85.54
#                 Rossville	                 GRAND LARCENY	18	37.50
#              Howland Hook	                FELONY ASSAULT	26	36.62
# Bloomfield-Chelsea-Travis	                 GRAND LARCENY	41	48.81
#               City Island	                 GRAND LARCENY	11	31.43
# Charlestown-Richmond Valley	                 GRAND LARCENY	6	35.29
#                  Flatbush	                 GRAND LARCENY	5	50.00
#                  Huguenot	                 GRAND LARCENY	17	47.22
#                 Annandale	                 GRAND LARCENY	13	44.83
#                  Rosebank	                FELONY ASSAULT	1	50.00
#                   Bayside	                      BURGLARY	1	100.00

# %% [markdown]
# **Q1: _Which is the street in New York City with the highest density of crime? (e.g., the highest concentration of criminal activity w.r.t. its lenght)_**
